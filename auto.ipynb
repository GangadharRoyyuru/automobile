# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df= pd.read_csv("auto-mpg.csv", na_values = {
    'hp':['?']
})
df
# Out:
#       mpg  cyl   disp     hp    wt   acc  yr  origin  \
# 0    18.0    8  307.0  130.0  3504  12.0  70       1
# 1    15.0    8  350.0  165.0  3693  11.5  70       1
# 2    18.0    8  318.0  150.0  3436  11.0  70       1
# 3    16.0    8  304.0  150.0  3433  12.0  70       1
# 4    17.0    8  302.0  140.0  3449  10.5  70       1
# ..    ...  ...    ...    ...   ...   ...  ..     ...
# 393  27.0    4  140.0   86.0  2790  15.6  82       1
# 394  44.0    4   97.0   52.0  2130  24.6  82       2
# 395  32.0    4  135.0   84.0  2295  11.6  82       1
# 396  28.0    4  120.0   79.0  2625  18.6  82       1
# 397  31.0    4  119.0   82.0  2720  19.4  82       1
#
#                       car name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df["hp"].fillna(value=df["hp"].mean(), inplace = True)
df
# Out:
#       mpg  cyl   disp     hp    wt   acc  yr  origin  \
# 0    18.0    8  307.0  130.0  3504  12.0  70       1
# 1    15.0    8  350.0  165.0  3693  11.5  70       1
# 2    18.0    8  318.0  150.0  3436  11.0  70       1
# 3    16.0    8  304.0  150.0  3433  12.0  70       1
# 4    17.0    8  302.0  140.0  3449  10.5  70       1
# ..    ...  ...    ...    ...   ...   ...  ..     ...
# 393  27.0    4  140.0   86.0  2790  15.6  82       1
# 394  44.0    4   97.0   52.0  2130  24.6  82       2
# 395  32.0    4  135.0   84.0  2295  11.6  82       1
# 396  28.0    4  120.0   79.0  2625  18.6  82       1
# 397  31.0    4  119.0   82.0  2720  19.4  82       1
#
#                       car name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 393            ford mustang gl
# 394                  vw pickup
# 395              dodge rampage
# 396                ford ranger
# 397                 chevy s-10
#
# [398 rows x 9 columns]

# %%
sns.pairplot(df)

# %%
corr  =df.corr()
corr
# Out:
#              mpg       cyl      disp        hp        wt       acc        yr  \
# mpg     1.000000 -0.775396 -0.804203 -0.771496 -0.831741  0.420289  0.579267
# cyl    -0.775396  1.000000  0.950721  0.839301  0.896017 -0.505419 -0.348746
# disp   -0.804203  0.950721  1.000000  0.894033  0.932824 -0.543684 -0.370164
# hp     -0.771496  0.839301  0.894033  1.000000  0.861043 -0.684805 -0.411016
# wt     -0.831741  0.896017  0.932824  0.861043  1.000000 -0.417457 -0.306564
# acc     0.420289 -0.505419 -0.543684 -0.684805 -0.417457  1.000000  0.288137
# yr      0.579267 -0.348746 -0.370164 -0.411016 -0.306564  0.288137  1.000000
# origin  0.563450 -0.562543 -0.609409 -0.453321 -0.581024  0.205873  0.180662
#
#           origin
# mpg     0.563450
# cyl    -0.562543
# disp   -0.609409
# hp     -0.453321
# wt     -0.581024
# acc     0.205873
# yr      0.180662
# origin  1.000000

# %%
sns.heatmap(corr, annot =True)
# Out:
# <AxesSubplot:>

# %%
df.hp
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: hp, Length: 398, dtype: float64

# %%
df.drop('car name', axis = 1, inplace = True)

# %%
df
# Out:
#       mpg  cyl   disp     hp    wt   acc  yr  origin
# 0    18.0    8  307.0  130.0  3504  12.0  70       1
# 1    15.0    8  350.0  165.0  3693  11.5  70       1
# 2    18.0    8  318.0  150.0  3436  11.0  70       1
# 3    16.0    8  304.0  150.0  3433  12.0  70       1
# 4    17.0    8  302.0  140.0  3449  10.5  70       1
# ..    ...  ...    ...    ...   ...   ...  ..     ...
# 393  27.0    4  140.0   86.0  2790  15.6  82       1
# 394  44.0    4   97.0   52.0  2130  24.6  82       2
# 395  32.0    4  135.0   84.0  2295  11.6  82       1
# 396  28.0    4  120.0   79.0  2625  18.6  82       1
# 397  31.0    4  119.0   82.0  2720  19.4  82       1
#
# [398 rows x 8 columns]

# %%
df.origin = df.origin.replace({1: '')
